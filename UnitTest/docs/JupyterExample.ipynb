# %% [markdown]
# # Jupyter Notebook Example

# %% [markdown]
# ## Here we include the notebook directly into Sphinx using nbsphinx

# %%
import pandoc
import matplotlib.pyplot as plt

# Data to display on the plot
x = [1, 2, 3]
y = [2, 4, 1]

# Create the plot
plt.plot(x, y)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('My first graph!')

# Display the plot
plt.show()

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\baugstein'
